# %%
# run once
import sys, os
import panelcode

# %%
# run each time
# %run paneler.py -i input/tests
# Out:
# ###  paneler.py  ###
# Start time: 2017-09-14 16:27:08
#
# 1 path filelists.
#
# Filelist:
# ['input/tests/blanks.panelcode.txt', 'input/tests/complex.panelcode.txt', 'input/tests/conversions.panelcode.txt', 'input/tests/examples.panelcode.txt', 'input/tests/groups.panelcode.txt', 'input/tests/rows.panelcode.txt']
#
# ...in path: input/tests
#   6 *.panelcode.txt files found
#
# Done.
# Elapsed time: 0:00:00
# Output in: ./log/out.txt
# FILENAME:
# input/tests/blanks.panelcode
# ./output/blanks.panelcode
# FILENAME:
# input/tests/complex.panelcode
# ./output/complex.panelcode
# FILENAME:
# input/tests/conversions.panelcode
# ./output/conversions.panelcode
# FILENAME:
# input/tests/examples.panelcode
# ./output/examples.panelcode
# FILENAME:
# input/tests/groups.panelcode
# ./output/groups.panelcode
# FILENAME:
# input/tests/rows.panelcode
# ./output/rows.panelcode

# %%
# %%bash
# zip -r output.zip output
# Out:
#   adding: output/ (stored 0%)
#   adding: output/.DS_Store (deflated 83%)
#   adding: output/blanks.panelcode/ (stored 0%)
#   adding: output/blanks.panelcode/0.svg (deflated 63%)
#   adding: output/blanks.panelcode/0_1_0.svg (deflated 67%)
#   adding: output/blanks.panelcode/index.html (deflated 37%)
#   adding: output/complex.panelcode/ (stored 0%)
#   adding: output/complex.panelcode/3(r2+1,1)_4(r2+1+r2,1)_4(1+r2+1,2).svg (deflated 71%)
#   adding: output/complex.panelcode/index.html (deflated 21%)
#   adding: output/conversions.panelcode/ (stored 0%)
#   adding: output/conversions.panelcode/(3)_(3)_(3).svg (deflated 69%)
#   adding: output/conversions.panelcode/3(r2+1,1)_4(r2+1+r2,1)_4(1+r2+1,2).svg (deflated 71%)
#   adding: output/conversions.panelcode/3(r2+1,1)_4H_4I.svg (deflated 67%)
#   adding: output/conversions.panelcode/3_3_3.svg (deflated 68%)
#   adding: output/conversions.panelcode/4(1+r2+1,1+1).svg (deflated 64%)
# ...

# %%
## BROWSE OR DOWNLOAD
from IPython.display import display, HTML
browser_link_html = HTML('<h2><a href="output/" target="_blank">Browse output</h2>'
                       + '<h2><a href="output.zip" target="_blank">Download output.zip</h2>')
display(browser_link_html)
# Out:
# <h2><a href="output/" target="_blank">Browse output</h2>
# <h2><a href="output.zip" target="_blank">Download output.zip</h2>
